# %%
# %matplotlib notebook

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
final_df = pd.read_csv('./data_set/by-boro.csv')
lat_df = pd.read_csv('./data_set/lat_merge.csv')

# %%
lat_df.columns
# Out:
# Index(['Borough', 'case_rate', 'hospitalized_rate', 'death_rate', 'case_count',
#        'hospitalized_count', 'death_count', 'Year', ' Data ', 'Lat', 'Lng'],
#       dtype='object')

# %%
spec_chars = [",", "$"]


for char in spec_chars:
    lat_df[' Data '] = lat_df[' Data '].str.replace(char,'')

# %%
lat_df[" Data "] = lat_df[' Data '].astype(float)

# %%
borough_array = [lat_df["Borough"]]
#borough_data_array = [final.loc[:6]]
x_axis = np.arange(len(lat_df))

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["Bronx", "Brooklyn", "Manhattan", "Queens", "Staten Island"])
plt.title('Income By Borough')

borough_income_bar = plt.bar(x_axis, lat_df[" Data "])
# Out:
# <img src="data:image/png;base64,..." width="640">
