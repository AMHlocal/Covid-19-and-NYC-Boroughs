# %%
import os
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
median = "Data Set/QuickFacts Aug-06-2020.csv"
money_stuff_df = pd.read_csv(median)
#money_stuff_df.head()
#money_stuff_df.drop(money_stuff_df.columns.difference(['Median household income (in 2018 dollars), 2014-2018','Per capita income in past 12 months (in 2018 dollars), 2014-2018','Persons in poverty, percent']), inplace=True)
#money_stuff_df = money_stuff_df.loc[:, money_stuff_df.rows.intersection(['Median household income (in 2018 dollars), 2014-2018','Per capita income in past 12 months (in 2018 dollars), 2014-2018'])]
money_stuff_df.head()
# Out:
#                                                 Fact  \
# 0  Median household income (in 2018 dollars), 201...
# 1  Per capita income in past 12 months (in 2018 d...
# 2                        Persons in poverty, percent
# 3                                                NaN
# 4                                                NaN
#
#   New York County (Manhattan Borough), New York  \
# 0                                      $82,459
# 1                                      $72,832
# 2                                        15.60%
# 3                                           NaN
# 4                                           NaN
#
#   Bronx County (Bronx Borough), New York  \
# 0                               $38,085
# 1                               $20,850
# 2                                 27.30%
# 3                                    NaN
# 4                                    NaN
#
#   Queens County (Queens Borough), New York  \
# 0                                 $64,987
# 1                                 $30,289
# 2                                   11.60%
# 3                                      NaN
# 4                                      NaN
#
#   Kings County (Brooklyn Borough), New York  \
# 0                                  $56,015
# 1                                  $31,984
# 2                                    18.90%
# 3                                       NaN
# 4                                       NaN
#
#   Richmond County (Staten Island Borough), New York New York city, New York
# 0                                          $79,267                 $60,762
# 1                                          $34,987                 $37,693
# 2                                            11.70%                  18.90%
# 3                                               NaN                     NaN
# 4                                               NaN                     NaN

# %%
#almost_done = money_stuff_df.drop(money_stuff_df.index[0:44])
#almost_done.head()
#attempt = almost_done.drop(almost_done.tail(20).index,inplace=True)
#almost_done["New York County (Manhattan Borough), New York"] = pd.to_numeric(almost_done["New York County (Manhattan Borough), New York"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "$82,459 "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-2fc9acccc1e5> in <module>
#       2 #almost_done.head()
#       3 #attempt = almost_done.drop(almost_done.tail(20).index,inplace=True)
# ----> 4 almost_done["New York County (Manhattan Borough), New York"] = pd.to_numeric(almost_done["New York County (Manhattan Borough), New York"])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     148         try:
#     149             values = lib.maybe_convert_numeric(
# --> 150                 values, set(), coerce_numeric=coerce_numeric
#     151             )
#     152         except (ValueError, TypeError):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "$82,459 " at position 0

# %%
data = {'Borough': ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island'],
        'Average Median Household Income': ['38476', '61220', '85066', '69320', '82166']
       }
df = pd.DataFrame(data, columns = ['Borough', 'Average Median Household Income'])
df['Average Median Household Income'] = df['Average Median Household Income'].astype(float)
df.head()
# Out:
#          Borough  Average Median Household Income
# 0          Bronx                          38476.0
# 1       Brooklyn                          61220.0
# 2      Manhattan                          85066.0
# 3         Queens                          69320.0
# 4  Staten Island                          82166.0
