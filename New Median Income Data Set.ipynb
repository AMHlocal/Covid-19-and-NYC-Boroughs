# %%
import os
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
median = "Data Set/QuickFacts Aug-06-2020.csv"
money_stuff_df = pd.read_csv(median)
#money_stuff_df.head()
#money_stuff_df.drop(money_stuff_df.columns.difference(['Median household income (in 2018 dollars), 2014-2018','Per capita income in past 12 months (in 2018 dollars), 2014-2018','Persons in poverty, percent']), inplace=True)
#money_stuff_df = money_stuff_df.loc[:, money_stuff_df.rows.intersection(['Median household income (in 2018 dollars), 2014-2018','Per capita income in past 12 months (in 2018 dollars), 2014-2018'])]
money_stuff_df.head()
# Out:
#                                                 Fact  \
# 0  Median household income (in 2018 dollars), 201...
# 1  Per capita income in past 12 months (in 2018 d...
# 2                        Persons in poverty, percent
#
#   New York County (Manhattan Borough), New York  \
# 0                                         82459
# 1                                         72832
# 2                                        15.60%
#
#   Bronx County (Bronx Borough), New York  \
# 0                                  38085
# 1                                  20850
# 2                                 27.30%
#
#   Queens County (Queens Borough), New York  \
# 0                                    64987
# 1                                    30289
# 2                                   11.60%
#
#   Kings County (Brooklyn Borough), New York  \
# 0                                     56015
# 1                                     31984
# 2                                    18.90%
#
#   Richmond County (Staten Island Borough), New York New York city, New York
# 0                                             79267                   60762
# 1                                             34987                   37693
# 2                                            11.70%                  18.90%

# %%
before_swap = money_stuff_df.rename(columns={"New York County (Manhattan Borough), New York":"Manhattan", 
                                             "Bronx County (Bronx Borough), New York":"Bronx", 
                                             "Queens County (Queens Borough), New York":"Queens", 
                                             "Kings County (Brooklyn Borough), New York":"Brooklyn", 
                                             "Richmond County (Staten Island Borough), New York": "Staten Island"}
                                   )
before_swap.head()
# Out:
#                                                 Fact Manhattan   Bronx  \
# 0  Median household income (in 2018 dollars), 201...     82459   38085
# 1  Per capita income in past 12 months (in 2018 d...     72832   20850
# 2                        Persons in poverty, percent    15.60%  27.30%
#
#    Queens Brooklyn Staten Island New York city, New York
# 0   64987    56015         79267                   60762
# 1   30289    31984         34987                   37693
# 2  11.60%   18.90%        11.70%                  18.90%

# %%
before_swap_transposed = before_swap.T
new_final = before_swap_transposed.rename(columns={"New York County (Manhattan Borough), New York":"Manhattan", 
                                             "Bronx County (Bronx Borough), New York":"Bronx", 
                                             "Queens County (Queens Borough), New York":"Queens", 
                                             "Kings County (Brooklyn Borough), New York":"Brooklyn", 
                                             "Richmond County (Staten Island Borough), New York": "Staten Island"}
                                   )
# Out:
#                                                                          0  \
# Fact                     Median household income (in 2018 dollars), 201...
# Manhattan                                                            82459
# Bronx                                                                38085
# Queens                                                               64987
# Brooklyn                                                             56015
# Staten Island                                                        79267
# New York city, New York                                              60762
#
#                                                                          1  \
# Fact                     Per capita income in past 12 months (in 2018 d...
# Manhattan                                                            72832
# Bronx                                                                20850
# Queens                                                               30289
# Brooklyn                                                             31984
# Staten Island                                                        34987
# New York city, New York                                              37693
#
#                                                    2
# Fact                     Persons in poverty, percent
# Manhattan                                     15.60%
# Bronx                                         27.30%
# Queens                                        11.60%
# Brooklyn                                      18.90%
# Staten Island                                 11.70%
# New York city, New York                       18.90%

# %%
data = {'Borough': ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island'],
        'Average Median Household Income': ['38476', '61220', '85066', '69320', '82166']
       }
df = pd.DataFrame(data, columns = ['Borough', 'Average Median Household Income'])
df['Average Median Household Income'] = df['Average Median Household Income'].astype(float)
df.head()
# Out:
#          Borough  Average Median Household Income
# 0          Bronx                          38476.0
# 1       Brooklyn                          61220.0
# 2      Manhattan                          85066.0
# 3         Queens                          69320.0
# 4  Staten Island                          82166.0
